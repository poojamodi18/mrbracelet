# %% [markdown]
# <a href="https://colab.research.google.com/github/poojamodi18/mrbracelet/blob/main/merge_all_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
main = pd.read_csv('Stock Report By Item Summary.csv')
main
# Out:
#        style_cd                            Description  onhand  Amount  \
# 0       5378LB5                 D 14.52 18KWY 41.91 GM     1.0   15725
# 1       6582LN1    PER DIAM 27.67 18KW 68.69 GM 504 ST     1.0   35883
# 2       6730LN7  D 9.95 BG 11.32 18KW 80.43 GM 1950 ST     1.0   36900
# 3        6P9985                     D 0.35 18KW  59 ST     1.0     340
# 4        7095CB                 D 4.40 18KW 12.00 GM ?     1.0    6279
# ...         ...                                    ...     ...     ...
# 11179  VLR1053Y                   D 0.55 18KYW 12.8 GM     5.0    4315
# 11180    VR3464                  D & BG 0.91 14KY 6 MM     1.0     772
# 11181  WEHH5237      D 0.16 BG 0.24 14KW 2.71 GM 61 ST     5.0    2710
# 11182   YF10R8F                  D 1.15 18KWRY  141 ST     1.0    2074
# 11183   YRN0012            D 1.23 14KW 12.39 GM 367 ST     1.0    1926
#
#        category
# 0      BRACELET
# 1      NECKLACE
# 2      NECKLACE
# 3       PENDANT
# 4      BRACELET
# ...

# %%
df_comp = pd.read_csv('Stock Report By Style Components.csv')
df_comp
# Out:
#       Item_style_cd   Rate  Type metal_color  Gm/Pc  Total Gm    Ctw
# 0           5378LB5  15725  18KT           L  41.91     41.91  14.52
# 1           6582LN1  35883  18KT           W  68.69     68.69  27.67
# 2           6730LN7  36900  18KT           W  80.43     80.43  21.27
# 3            6P9985    340  18KT           W   1.00      1.00   0.35
# 4            7095CB   6279  18KT           W  12.00     12.00   4.40
# ...             ...    ...   ...         ...    ...       ...    ...
# 11179      VLR1053Y    863  18KT           L  12.08     60.40   0.55
# 11180        VR3464    772  14KT           Y   1.00      1.00   0.91
# 11181      WEHH5237    542  14KT           W   2.71     13.55   0.40
# 11182       YF10R8F   2074  18KT           E   4.00      4.00   1.15
# 11183       YRN0012   1926  14KT           W  12.39     12.39   1.23
#
# [11184 rows x 7 columns]

# %%
df_size = pd.read_csv('Stock Report By Item-Size.csv')
df_size
# Out:
#          Item_num  Size  Pcs  Amount
# 0       HKR00404D     7  1.0    1733
# 1        NETQ3606     7  3.0    1860
# 2           RG906     7  1.0     445
# 3            0603     7  1.0    2418
# 4            3502     7  1.0    3019
# ...           ...   ...  ...     ...
# 44855     Z22424A     7  1.0     287
# 44856     Z23193A     7  1.0     194
# 44857  Z23193A/18     7  9.0    2394
# 44858  Z23193A/20     7  3.0     813
# 44859     Z23193B     7  4.0     832
#
# [44860 rows x 4 columns]

# %%
aggregated_size_df = df_size.groupby('Item_num')['Size'].max().reset_index()
aggregated_size_df
# Out:
#          Item_num  Size
# 0       HKR00404D     7
# 1        NETQ3606     7
# 2           RG906     7
# 3            0603     7
# 4            3502     7
# ...           ...   ...
# 44833     Z22424A     7
# 44834     Z23193A     7
# 44835  Z23193A/18     7
# 44836  Z23193A/20     7
# 44837     Z23193B     7
#
# [44838 rows x 2 columns]

# %%
merged_df = pd.merge(main, aggregated_size_df[['Item_num', 'Size']], left_on='style_cd', right_on='Item_num', how='left')

# Drop the redundant 'Item_num' column
merged_df.drop('Item_num', axis=1, inplace=True)

merged_df
# Out:
#        style_cd                            Description  onhand  Amount  \
# 0       5378LB5                 D 14.52 18KWY 41.91 GM     1.0   15725
# 1       6582LN1    PER DIAM 27.67 18KW 68.69 GM 504 ST     1.0   35883
# 2       6730LN7  D 9.95 BG 11.32 18KW 80.43 GM 1950 ST     1.0   36900
# 3        6P9985                     D 0.35 18KW  59 ST     1.0     340
# 4        7095CB                 D 4.40 18KW 12.00 GM ?     1.0    6279
# ...         ...                                    ...     ...     ...
# 11179  VLR1053Y                   D 0.55 18KYW 12.8 GM     5.0    4315
# 11180    VR3464                  D & BG 0.91 14KY 6 MM     1.0     772
# 11181  WEHH5237      D 0.16 BG 0.24 14KW 2.71 GM 61 ST     5.0    2710
# 11182   YF10R8F                  D 1.15 18KWRY  141 ST     1.0    2074
# 11183   YRN0012            D 1.23 14KW 12.39 GM 367 ST     1.0    1926
#
#        category  Size
# 0      BRACELET     7
# 1      NECKLACE     7
# 2      NECKLACE     7
# ...

# %%
total_df = pd.merge(main, df_comp[['Item_style_cd', 'Type', 'metal_color', 'Total Gm', 'Ctw']], left_on='style_cd', right_on='Item_style_cd', how='left')

# Drop the redundant 'Item_num' column
total_df.drop('Item_style_cd', axis=1, inplace=True)

total_df
# Out:
#        style_cd                            Description  onhand  Amount  \
# 0       5378LB5                 D 14.52 18KWY 41.91 GM     1.0   15725
# 1       6582LN1    PER DIAM 27.67 18KW 68.69 GM 504 ST     1.0   35883
# 2       6730LN7  D 9.95 BG 11.32 18KW 80.43 GM 1950 ST     1.0   36900
# 3        6P9985                     D 0.35 18KW  59 ST     1.0     340
# 4        7095CB                 D 4.40 18KW 12.00 GM ?     1.0    6279
# ...         ...                                    ...     ...     ...
# 11179  VLR1053Y                   D 0.55 18KYW 12.8 GM     5.0    4315
# 11180    VR3464                  D & BG 0.91 14KY 6 MM     1.0     772
# 11181  WEHH5237      D 0.16 BG 0.24 14KW 2.71 GM 61 ST     5.0    2710
# 11182   YF10R8F                  D 1.15 18KWRY  141 ST     1.0    2074
# 11183   YRN0012            D 1.23 14KW 12.39 GM 367 ST     1.0    1926
#
#        category  Type metal_color  Total Gm    Ctw
# 0      BRACELET  18KT           L     41.91  14.52
# ...

# %%
total_df.to_csv("combined_data.csv", encoding='utf-8', index=False)
